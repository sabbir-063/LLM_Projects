# %% [markdown]
# # get env variable

# %%
from google.colab import userdata
# userdata.get('HF_TOKEN')

# %% [markdown]
# # huggingface chat models

# %%
from huggingface_hub import InferenceClient
# from google.colab import userdata

# client = InferenceClient("mistralai/Mixtral-8x7B-Instruct-v0.1", token=userdata.get('HF_TOKEN'))
# client = InferenceClient("Qwen/Qwen3-Coder-480B-A35B-Instruct", token=userdata.get('HF_TOKEN'))
# client = InferenceClient("deepseek-ai/DeepSeek-R1", token=userdata.get('HF_TOKEN'))
client = InferenceClient("meta-llama/Llama-3.1-8B-Instruct", token=userdata.get('HF_TOKEN'))

output = client.chat_completion(
    messages=[{"role": "user", "content": "What is the capital of France?"}]
)

print(output.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# # gemini chat models

# %%
# !pip install -q langchain langchain-google-genai google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.7 MB/s eta 0:00:00

# %%
import os

# Replace with your real API key or use os.environ if already set in Colab
os.environ["GOOGLE_API_KEY"] = "AIzaSyCBfr5-35mPy-PvG7vYS1g1ObJlR4jzBnA"

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

# %%
response = model.invoke("What is the capital of bd?")
print(response.content)
# Out:
# The capital of Bangladesh is **Dhaka**.

# %%
# !pip install langchain-community

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://cmed.com.bd/jobs/junior-flutter-app-developer/")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Junior Flutter App Developer – CMED Health
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
# Company
#
# About Us
# Leadership & Management
# Our Advisors
# Grants
#
# Susastho.AI Chatbot
#
#
#
#
# Services
#
# Employee Wellness Solution (DHC)
# Smart SuSastho Kormi
# Digital General Practitioner (GP)
# Health Projects
# Satisfaction Survey Kiosk System
# Smart Products
# Smart Chamber
# Public Health & Advocacy
# Healthy Mom, Healthy Baby (HMHB)
# Model Enterprise Clinic
#
#
# Gallery
# Contact Us
#
# Local Office
# Global Office
#
#
# Procurement
# Login
# Career
#
#
#
#
#
#
#
#
#
#
# Home
# Company
#
# About Us
# Leadership & Management
# Our Advisors
# Grants
#
# Susastho.AI Chatbot
#
#
#
#
# Services
#
# Employee Wellness Solution (DHC)
# Smart SuSastho Kormi
# Digital General Practitioner (GP)
# Health Projects
# ...

# %%
# !pip install langchain-core

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):
        """
)

chain_extract = prompt_extract | model
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
print(res.content)
# Out:
# ```json
# [
#   {
#     "role": "Junior Flutter App Developer",
#     "experience": "At least 1/2 year(s) experience, 1 to 2 years of experience in relevant positions.",
#     "skills": [
#       "Flutter",
#       "Android Development",
#       "iOS Development",
#       "MVP/MVVM",
#       "Getx",
#       "Block",
#       "Provider",
#       "Flutter widgets and their life cycle",
#       "OOP",
#       "Algorithms",
#       "Data Structures",
#       "REST APIs",
#       "UI/UX Design Collaboration",
#       "Software Testing Collaboration",
#       "Git",
#       "Google Firebase",
#       "Google Play Store Deployment",
#       "Apple App Store Deployment",
#       "Pixel-perfect UI design",
#       "App lifecycle understanding",
#       "API Integration",
#       "Payment Gateway Integration",
#       "User-Centric Focus",
#       "Code Translation",
#       "JSON Data Handling",
#       "Problem-Solving",
#       "Team Player",
#       "Push Notifications",
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Junior Flutter App Developer',
#   'experience': 'At least 1/2 year(s) experience, 1 to 2 years of experience in relevant positions.',
#   'skills': ['Flutter',
#    'Android Development',
#    'iOS Development',
#    'MVP/MVVM',
#    'Getx',
#    'Block',
#    'Provider',
#    'Flutter widgets and their life cycle',
#    'OOP',
#    'Algorithms',
#    'Data Structures',
#    'REST APIs',
#    'UI/UX Design Collaboration',
#    'Software Testing Collaboration',
#    'Git',
#    'Google Firebase',
#    'Google Play Store Deployment',
#    'Apple App Store Deployment',
#    'Pixel-perfect UI design',
#    'App lifecycle understanding',
#    'API Integration',
#    'Payment Gateway Integration',
#    'User-Centric Focus',
#    'Code Translation',
#    'JSON Data Handling',
#    'Problem-Solving',
#    'Team Player',
#    'Push Notifications',
#    'Google Map Integration',
#    'Third-party libraries integration',
#    'SDKs integration'],
# ...

# %%
type(json_res)
# Out:
# list

# %%
# /content/drive/MyDrive/Colab Notebooks/resources/my_portfolio.csv
# view link of resource folder
# https://drive.google.com/drive/folders/1rE-WaFmrHmjXfDV53Nc3X104o-FlHCo6?usp=sharing

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/resources/my_portfolio.csv")
df.head()
# Out:
#                            Techstack                                  Links
# 0            React, Node.js, MongoDB    https://example.com/react-portfolio
# 1           Angular,.NET, SQL Server  https://example.com/angular-portfolio
# 2  Vue.js, Ruby on Rails, PostgreSQL      https://example.com/vue-portfolio
# 3              Python, Django, MySQL   https://example.com/python-portfolio
# 4          Java, Spring Boot, Oracle     https://example.com/java-portfolio

# %% [markdown]
# # chromadb

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 74.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 82.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 13.4 MB/s eta 0:00:00
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('/content/drive/MyDrive/Colab Notebooks/vector_databases/vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 81.4MiB/s]

# %%
job = json_res[0]
job['skills']
# Out:
# ['Flutter',
#  'Android Development',
#  'iOS Development',
#  'MVP/MVVM',
#  'Getx',
#  'Block',
#  'Provider',
#  'Flutter widgets and their life cycle',
#  'OOP',
#  'Algorithms',
#  'Data Structures',
#  'REST APIs',
#  'UI/UX Design Collaboration',
#  'Software Testing Collaboration',
#  'Git',
#  'Google Firebase',
#  'Google Play Store Deployment',
#  'Apple App Store Deployment',
#  'Pixel-perfect UI design',
#  'App lifecycle understanding',
#  'API Integration',
#  'Payment Gateway Integration',
#  'User-Centric Focus',
#  'Code Translation',
#  'JSON Data Handling',
#  'Problem-Solving',
#  'Team Player',
#  'Push Notifications',
#  'Google Map Integration',
#  'Third-party libraries integration',
#  'SDKs integration']

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/flutter-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/android-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/ios-portfolio'}],
#  [{'links': 'https://example.com/android-tv-portfolio'},
#   {'links': 'https://example.com/android-portfolio'}],
#  [{'links': 'https://example.com/android-tv-portfolio'},
#   {'links': 'https://example.com/xamarin-portfolio'}],
#  [{'links': 'https://example.com/android-tv-portfolio'},
#   {'links': 'https://example.com/android-portfolio'}],
#  [{'links': 'https://example.com/kotlin-android-portfolio'},
#   {'links': 'https://example.com/android-tv-portfolio'}],
#  [{'links': 'https://example.com/flutter-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/java-portfolio'},
# ...

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Sabbir, a business development executive at MSM Technology. MSM Technology is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools.
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability,
        process optimization, cost reduction, and heightened overall efficiency.
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of MSM Technology
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase MSM Technology's portfolio: {link_list}
        Remember you are Sabbir, BDE at MSM Technology.
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

chain_email = prompt_email | model
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Streamlining Mobile App Development with MSM Technology
#
# Dear [Hiring Manager Name],
#
# I hope this email finds you well.
#
# My name is Sabbir, and I'm a Business Development Executive at MSM Technology, an AI & Software Consulting company. I came across your job posting for a Junior Flutter App Developer and was immediately impressed with the scope and requirements.
#
# At MSM Technology, we specialize in providing tailored solutions to businesses looking to optimize their processes and enhance efficiency through automation. We have a strong track record of empowering enterprises with scalable and cost-effective solutions.
#
# We believe our expertise aligns perfectly with your need for a skilled Flutter developer. Our team has extensive experience in:
#
# *   **Flutter App Development:** Building cross-platform Android and iOS applications with seamless user experiences.
# ...
